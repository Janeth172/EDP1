# %% [markdown]
# <a href="https://colab.research.google.com/github/Janeth172/EDP1/blob/main/Jacobi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **METÓDO ITERATIVO DE JACOBI**

# %%
import numpy as np
import pandas as pd
from IPython.display import display

pd.set_option("display.precision", 8)
pd.set_option("display.width", 140)

# Funcion de jacobi
def jacobi(A, b, x0, TOL, N, nombres):
    A = np.array(A, dtype=float)
    b = np.array(b, dtype=float).reshape(-1)
    x_old = np.array(x0, dtype=float).reshape(-1)
    n = A.shape[0]

    if nombres is None:
        nombres = [f"x{i+1}" for i in range(n)]

    historial = []
    exito = False

# Iteración 0
    fila0 = {"iter": 0}
    for name, val in zip(nombres, x_old):
        fila0[name] = val
    historial.append(fila0)

# Paso 1
    k = 1

# Paso 2
    while k <= N:
        x_new = np.zeros_like(x_old)

# Paso 3
        for i in range(n):
            aii = A[i, i]
            suma = sum(A[i, j]*x_old[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - suma) / aii

# Paso 4
        err_inf = np.linalg.norm(x_new - x_old, ord=np.inf)

        fila = {"iter": k}
        for name, val in zip(nombres, x_new):
            fila[name] = val
        fila["err_inf"] = err_inf
        historial.append(fila)

        if err_inf < TOL:
            exito = True
            x_final = x_new.copy()
            break

# Paso 5
        k += 1

# Paso 6
        x_old = x_new

    if not exito:
        x_final = x_old

# Se construye la tabla
    cols = ["iter"] + nombres
    tabla = pd.DataFrame(historial)[cols]

    return x_final, tabla, exito


# Se escribe aqui el sistema

A = [[4, -1, -1, 0],
     [1, -4, 0, 1],
     [1, 0, -4, 1],
     [0, 1, 1, -4]]

#   si en la diagonal hay ceros, es necesario
#   intercambiar reenglones, no debe haber
#   ceros en la diagonal

b = [0, -2/3, -8/9, -14/9]

# Parametros del problema

x0  = [0, 0, 0, 0]
TOL = 1e-10
N   = 100

# Ejecucion de la función Jacobi
x_aprox, tabla, exito = jacobi(A, b, x0, TOL, N, nombres=["A","B","C","D"])

# Imprime la tabla
display(tabla.style.hide(axis="index"))

# Imprime el vector solucion
print("Solución aproximada X=(A, B, C, D):", x_aprox)
# Out:
# <style type="text/css">
# </style>
# <table id="T_37bd5" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_37bd5_level0_col0" class="col_heading level0 col0" >iter</th>
#       <th id="T_37bd5_level0_col1" class="col_heading level0 col1" >A</th>
#       <th id="T_37bd5_level0_col2" class="col_heading level0 col2" >B</th>
#       <th id="T_37bd5_level0_col3" class="col_heading level0 col3" >C</th>
#       <th id="T_37bd5_level0_col4" class="col_heading level0 col4" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_37bd5_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_37bd5_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_37bd5_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_37bd5_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_37bd5_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_37bd5_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_37bd5_row1_col2" class="data row1 col2" >0.166667</td>
#       <td id="T_37bd5_row1_col3" class="data row1 col3" >0.222222</td>
#       <td id="T_37bd5_row1_col4" class="data row1 col4" >0.388889</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_37bd5_row2_col1" class="data row2 col1" >0.097222</td>
#       <td id="T_37bd5_row2_col2" class="data row2 col2" >0.263889</td>
#       <td id="T_37bd5_row2_col3" class="data row2 col3" >0.319444</td>
#       <td id="T_37bd5_row2_col4" class="data row2 col4" >0.486111</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_37bd5_row3_col1" class="data row3 col1" >0.145833</td>
#       <td id="T_37bd5_row3_col2" class="data row3 col2" >0.312500</td>
#       <td id="T_37bd5_row3_col3" class="data row3 col3" >0.368056</td>
#       <td id="T_37bd5_row3_col4" class="data row3 col4" >0.534722</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_37bd5_row4_col1" class="data row4 col1" >0.170139</td>
#       <td id="T_37bd5_row4_col2" class="data row4 col2" >0.336806</td>
#       <td id="T_37bd5_row4_col3" class="data row4 col3" >0.392361</td>
#       <td id="T_37bd5_row4_col4" class="data row4 col4" >0.559028</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_37bd5_row5_col1" class="data row5 col1" >0.182292</td>
#       <td id="T_37bd5_row5_col2" class="data row5 col2" >0.348958</td>
#       <td id="T_37bd5_row5_col3" class="data row5 col3" >0.404514</td>
#       <td id="T_37bd5_row5_col4" class="data row5 col4" >0.571181</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_37bd5_row6_col1" class="data row6 col1" >0.188368</td>
#       <td id="T_37bd5_row6_col2" class="data row6 col2" >0.355035</td>
#       <td id="T_37bd5_row6_col3" class="data row6 col3" >0.410590</td>
#       <td id="T_37bd5_row6_col4" class="data row6 col4" >0.577257</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_37bd5_row7_col1" class="data row7 col1" >0.191406</td>
#       <td id="T_37bd5_row7_col2" class="data row7 col2" >0.358073</td>
#       <td id="T_37bd5_row7_col3" class="data row7 col3" >0.413628</td>
#       <td id="T_37bd5_row7_col4" class="data row7 col4" >0.580295</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_37bd5_row8_col1" class="data row8 col1" >0.192925</td>
#       <td id="T_37bd5_row8_col2" class="data row8 col2" >0.359592</td>
#       <td id="T_37bd5_row8_col3" class="data row8 col3" >0.415148</td>
#       <td id="T_37bd5_row8_col4" class="data row8 col4" >0.581814</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_37bd5_row9_col1" class="data row9 col1" >0.193685</td>
#       <td id="T_37bd5_row9_col2" class="data row9 col2" >0.360352</td>
#       <td id="T_37bd5_row9_col3" class="data row9 col3" >0.415907</td>
#       <td id="T_37bd5_row9_col4" class="data row9 col4" >0.582574</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_37bd5_row10_col1" class="data row10 col1" >0.194065</td>
#       <td id="T_37bd5_row10_col2" class="data row10 col2" >0.360731</td>
#       <td id="T_37bd5_row10_col3" class="data row10 col3" >0.416287</td>
#       <td id="T_37bd5_row10_col4" class="data row10 col4" >0.582954</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_37bd5_row11_col1" class="data row11 col1" >0.194255</td>
#       <td id="T_37bd5_row11_col2" class="data row11 col2" >0.360921</td>
#       <td id="T_37bd5_row11_col3" class="data row11 col3" >0.416477</td>
#       <td id="T_37bd5_row11_col4" class="data row11 col4" >0.583143</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_37bd5_row12_col1" class="data row12 col1" >0.194350</td>
#       <td id="T_37bd5_row12_col2" class="data row12 col2" >0.361016</td>
#       <td id="T_37bd5_row12_col3" class="data row12 col3" >0.416572</td>
#       <td id="T_37bd5_row12_col4" class="data row12 col4" >0.583238</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_37bd5_row13_col1" class="data row13 col1" >0.194397</td>
#       <td id="T_37bd5_row13_col2" class="data row13 col2" >0.361064</td>
#       <td id="T_37bd5_row13_col3" class="data row13 col3" >0.416619</td>
#       <td id="T_37bd5_row13_col4" class="data row13 col4" >0.583286</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row14_col0" class="data row14 col0" >14</td>
#       <td id="T_37bd5_row14_col1" class="data row14 col1" >0.194421</td>
#       <td id="T_37bd5_row14_col2" class="data row14 col2" >0.361087</td>
#       <td id="T_37bd5_row14_col3" class="data row14 col3" >0.416643</td>
#       <td id="T_37bd5_row14_col4" class="data row14 col4" >0.583310</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row15_col0" class="data row15 col0" >15</td>
#       <td id="T_37bd5_row15_col1" class="data row15 col1" >0.194433</td>
#       <td id="T_37bd5_row15_col2" class="data row15 col2" >0.361099</td>
#       <td id="T_37bd5_row15_col3" class="data row15 col3" >0.416655</td>
#       <td id="T_37bd5_row15_col4" class="data row15 col4" >0.583321</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row16_col0" class="data row16 col0" >16</td>
#       <td id="T_37bd5_row16_col1" class="data row16 col1" >0.194439</td>
#       <td id="T_37bd5_row16_col2" class="data row16 col2" >0.361105</td>
#       <td id="T_37bd5_row16_col3" class="data row16 col3" >0.416661</td>
#       <td id="T_37bd5_row16_col4" class="data row16 col4" >0.583327</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row17_col0" class="data row17 col0" >17</td>
#       <td id="T_37bd5_row17_col1" class="data row17 col1" >0.194441</td>
#       <td id="T_37bd5_row17_col2" class="data row17 col2" >0.361108</td>
#       <td id="T_37bd5_row17_col3" class="data row17 col3" >0.416664</td>
#       <td id="T_37bd5_row17_col4" class="data row17 col4" >0.583330</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row18_col0" class="data row18 col0" >18</td>
#       <td id="T_37bd5_row18_col1" class="data row18 col1" >0.194443</td>
#       <td id="T_37bd5_row18_col2" class="data row18 col2" >0.361110</td>
#       <td id="T_37bd5_row18_col3" class="data row18 col3" >0.416665</td>
#       <td id="T_37bd5_row18_col4" class="data row18 col4" >0.583332</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row19_col0" class="data row19 col0" >19</td>
#       <td id="T_37bd5_row19_col1" class="data row19 col1" >0.194444</td>
#       <td id="T_37bd5_row19_col2" class="data row19 col2" >0.361110</td>
#       <td id="T_37bd5_row19_col3" class="data row19 col3" >0.416666</td>
#       <td id="T_37bd5_row19_col4" class="data row19 col4" >0.583333</td>
#     </tr>
#     <tr>
#       <td id="T_37bd5_row20_col0" class="
# Solución aproximada X=(A, B, C, D): [0.19444444 0.36111111 0.41666667 0.58333333]
