# %% [markdown]
# <a href="https://colab.research.google.com/github/Janeth172/EDP1/blob/main/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="brown"> Grafica  de $y=x^2$ </font>
# <font color="green"> ☘
#
# ![Vectores e ilustraciones de Aprender para descargar gratis _ Freepik.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-5,5,200)
plt.plot(x**2)
