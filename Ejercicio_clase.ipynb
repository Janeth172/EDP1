# %%
from sympy import *

# %% [markdown]
# Libreria para hacer calculos simbolicos.Permite hacer operaciones analíticas o con símbolos en lugar de con valores numéricos

# %%
x=symbols('x') #SE TOMA COMO VARIABLE

# %% [markdown]
# Utilizamos a la variable $x$ como simbolo

# %%
x**2+5    #EJEMPLO QUE DIO EL PROFE
# Out:
# x**2 + 5

# %%
c1=plotting.plot(x*x)  #TRAZA LA GRÀFICA DE LA FUNCIÒN x^2

# %% [markdown]
# Traza la gràfica de la funcion $y = x^2$

# %%
cl=plotting.plot(x*x,show=False)
c2=plotting.plot(x**3,show=False)

# %% [markdown]
# $show=False$ : Permite no mostrar las gràficas momentaneamente por si se requiere modificar algun dato

# %%
c1 #Indica qué es y en qué espacio de memoria está

# %%
c1.append(c2[0]) #Anida las gráficas sin los ejes

# %% [markdown]
# Se utiliza para agregar un elemento al final de una lista

# %%
c1

# %%
c1.show()    #MUESTRA LA GRAFICA DE LA PRIMERA FUNCION

# %% [markdown]
# Grafica la funcion

# %%
c1.extend(c2) #AGREGAR ELEMENTOS AL FINAL DE UNA LISTA

# %% [markdown]
# Permite agregar todos los elementos de un iterable(lista, tupla, cadena, etc) al final de una lista

# %%
c1.show()   #MUESTRA TODAS LAS FIGURAS

# %% [markdown]
# Muestra todas las graficas, es dcir, grafica las funciones

# %%
c2.show() #MUESTRA TODOS LAS FIGURAS

# %% [markdown]
# Grafica la segunda funcion $c_2$

# %%
from sympy.plotting import plot

# %% [markdown]
# Es una forma de importar la funcion $plot$ de la biblioteca $sympy$ que permite graficar expresiones analiticas

# %%
plot(x**2)

# %% [markdown]
# Grafica la funciòn $x^2$

# %%
plot(x**2,(x,-1,1))

# %% [markdown]
# Grafica la funcion, pero especifica las dimensiones del plano en el eje $x$

# %%
plot(exp(x))
#plot(exp(x),(x,0,2))

# %% [markdown]
# Grafica la funcion

# %%
plot(x,x**2,x**3, (x,-2,2))

# %% [markdown]
# Grafica tres funciones, $x, x^2, x^3$ y especifica las dimenciones del eje $x$

# %%
plot(x**2,adaptative=False,nb_of_points=10) #Revisar

# %% [markdown]
# *   Grafica la funciòn $f(x) = x^2$
# *   $adaptative = False$ : Desactiva la adaptacion automatica de la cantidad de puntos usados para dibujar la grafica
# *   $nb -of -points =10$: Especifica el numero de puntos que se usaran para trazar la grafica

# %% [markdown]
# ### Curvas parametrizadas

# %%
from sympy import plot_parametric

# %% [markdown]
# Grafica curvas parametricas en un plano 2D

# %%
s=symbols('s')

# %% [markdown]
# Usa la variable $s$

# %%
plot_parametric((cos(s)),sin(s))

# %%
plot_parametric((cos(s),sin(s)),(s,s**2),(s,-4,4))

# %%
c2[0].line_color='green'

# %%
c2.show()

# %% [markdown]
# ### Graficas 3D

# %%
from sympy.plotting import plot3d

# %%
x,y=symbols('x y')

# %%
plot3d(x*y)

# %%
plot3d(x*y, (x,-5,5),(y,-5,5))

# %%
plot3d(x*y, -x*y, (x,-5,5),(y,-5,5))

# %%
plot3d((x**2 + y**2, (x,-5,5),(y,-5,5)),(x*y,(x,-3,3),(y,-3,3)))

# %%
from sympy.plotting import plot3d_parametric_line

# %%
plot3d_parametric_line(cos(s),sin(s),s)

# %%
plot3d_parametric_line((cos(s),sin(s),s,(s,-5,5)),(sin(s),s**2,s,(s,-5,5)))

# %%
from sympy.plotting import plot3d_parametric_surface

# %%
u, v =symbols('u v')

# %%
plot3d_parametric_surface(cos(u+v),sin(u-v),u-v)

# %%
plot3d_parametric_surface(cos(v)*cos(u),cos(v)*sin(u),sin(v))

# %% [markdown]
# Funciones implícitas

# %%
from sympy import plot_implicit, symbols, Eq, And

# %%
x, y = symbols(' x y')

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
p6 = plot_implicit(y > x**2)

# %%
p6 = plot_implicit(And(y > x, y > -x))

# %% [markdown]
# CODIGO DE CLASE

# %%
from sympy.plotting import plot3d

# %%
from sympy import *

# %%
x,y=symbols('x y')   #ASIGNA LAS LETRAS DE LAS VARIABLES A USAR

# %%
plot3d(x**3-x*y + y**3,(x,-5,5),(y,-5,5))
